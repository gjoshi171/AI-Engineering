# %%
from pydantic import BaseModel

import cohere

from langchain_openai import ChatOpenAI
from langchain_core.tools import tool

from langsmith import traceable, get_current_run_tree

import instructor

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langgraph.types import Send

from langchain_core.messages import SystemMessage, convert_to_openai_messages, HumanMessage
from IPython.display import Image, display

from typing import Literal, Dict, Any, Annotated, List
from pydantic import Field
from operator import add

import random
import openai
import pandas as pd

from jinja2 import Template

from qdrant_client import QdrantClient
from qdrant_client import models
from qdrant_client.models import VectorParams, Distance, SparseVectorParams, Modifier, PayloadSchemaType, PointStruct, Document, Prefetch, FusionQuery

# %% [markdown]
# ### Agent Graph with Loopback from Tools(ReAct Agent)

# %%
@traceable(
    name="embed_query",
    run_type="embedding",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "text-embedding-3-small"
    }
)
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model
    )

    current_run = get_current_run_tree()
    if current_run:
        current_run.metadata["usage_metadata"] = {
            "input_tokens": response.usage.prompt_tokens,
            "total_tokens": response.usage.total_tokens,
        }

    return response.data[0].embedding


@traceable(
    name="retrieve_data",
    run_type="retriever"
)
def retrieve_data(query, qdrant_client, k=5, hybrid=True):

    query_embedding = get_embedding(query)

    if hybrid:
        results = qdrant_client.query_points(
            collection_name="Amazon-items-collection-01-hybrid-search",
            prefetch=[
                Prefetch(
                    query=query_embedding,
                    using="text-embedding-3-small",
                    limit=20
                ),
                Prefetch(
                    query=Document(
                        text=query,
                        model="qdrant/bm25"
                    ),
                    using="bm25",
                    limit=20
                )
            ],
            query=models.RrfQuery(rrf=models.Rrf(weights=[3,1])),
            limit=k
        )
    else:
        results = qdrant_client.query_points(
            collection_name="Amazon-items-collection-01-hybrid-search",
            query=query_embedding,
            using="text-embedding-3-small",
            limit=k
        )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []
    retrieved_context_ratings = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["preprocessed_description"])
        similarity_scores.append(result.score)
        retrieved_context_ratings.append(result.payload["average_rating"])

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "similarity_scores": similarity_scores,
        "retrieved_context_ratings": retrieved_context_ratings
    }


@traceable(
    name="rerank_data",
    run_type="tool"
)
def rerank_data(query, context, top_k=5):

    cohere_client = cohere.ClientV2()

    response = cohere_client.rerank(
        model="rerank-v4.0-pro",
        query=query,
        documents=context["retrieved_context"],
        top_n=top_k
    )

    order = [result.index for result in response.results]

    return {
        "retrieved_context_ids": [context["retrieved_context_ids"][i] for i in order],
        "retrieved_context": [context["retrieved_context"][i] for i in order],
        "similarity_scores": [context["similarity_scores"][i] for i in order],
        "retrieved_context_ratings": [context["retrieved_context_ratings"][i] for i in order]
    }


@traceable(
    name="format_retrieved_context",
    run_type="prompt"
)
def process_context(context):

    formatted_context = ""

    for id, chunk, rating in zip(context["retrieved_context_ids"], context["retrieved_context"], context["retrieved_context_ratings"]):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return formatted_context


@tool
def get_formatted_item_context(query:str, top_k: int = 5):
    """Get the top k context, each representing an inventory item for a given query.
    
    Args:
        query: The query to get the top k context for
        top_k: The number of context chunks to retrieve, works best with 5 or more
    
    Returns:
        A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.
    """

    qdrant_client = QdrantClient(url="http://localhost:6333")

    retrieved_context = retrieve_data(
        query,
        qdrant_client,
        k=20
    )

    retrieved_context = rerank_data(query, retrieved_context, top_k=top_k)
    formatted_context = process_context(retrieved_context)

    return formatted_context

# %% [markdown]
# ### State and Pydantic models for structured output

# %%
class RAGUsedContext(BaseModel):
    id: str = Field(description="ID of the item used to answer the question")
    description: str = Field(description="Description of the item used to answer the question")

class FinalResponse(BaseModel):
    answer: str = Field(description="Answer to the question")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question")

class State(BaseModel):
    messages: Annotated[List[Any], add] = []
    question_relevant: bool = False
    iteration: int = 0
    answer: str = ""
    final_answer: bool = False
    references: list[RAGUsedContext] = []

# %%
@traceable(
    name="agent_node",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def agent_node(state: State) -> dict:

    #jinja template
    prompt_template = """You are a shopping assistant that answers customer questions about products currently in stock.

## Instructions

- Use the available tools to answer product questions. Do not fabricate product details.
- When a question involves multiple products or sub-questions, issue all tool calls at once. Never repeat a tool call you already made.
- When describing products, include detailed specifications in bullet points.
- If tools return no relevant results, tell the customer and ask them to refine their query.
- Only answer questions about products in stock. If a question is unrelated, ask the customer to clarify what product they're interested in.
- In references, include every chunk that contributed to your answer with the chunk id and product name.
- Refer to retrieved data as "available products", never as "context".
- Try answering queries that are not precise, if specific names or brands are missing apply broad searches.
"""

    template = Template(prompt_template)
    prompt = template.render()

    llm = ChatOpenAI(
        model="gpt-5.4-mini",
        reasoning_effort="none",
        use_responses_api=True
    )

    #llm_with_tools 
    llm_with_tools = llm.bind_tools(
        [get_formatted_item_context, FinalResponse], #tools can be functions and pydantic model
        tool_choice="any",
    )

    response = llm_with_tools.invoke(
        [
            SystemMessage(content=prompt),
            *state.messages # message list to inject everytime we are running llm
        ]
    )

    final_answer = False
    answer= ""
    references= []

    if len(response.tool_calls) > 0:
        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalResponse":
                final_answer = True
                answer = tool_call.get("args").get("answer")
                references.extend(tool_call.get("args").get("references"))

    return {
        "messages": [response],
        "final_answer": final_answer,
        "iteration": state.iteration + 1,
        "answer": answer,
        "references": references
    }

# %%
def tool_router(state : State) -> str:

    if state.final_answer:
        return "end"
    elif state.iteration >2:
        return "end"
    elif len(state.messages[-1].tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %% [markdown]
# ### User Intent Router Node

# %%
class IntentRouterResponse(BaseModel):
    question_relevant: bool
    answer: str = Field(description="An answer to the question if the users question is not relevant to the products.")

# %%
@traceable(
    name="route_intent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def intent_router_node(state: State) -> dict:

    prompt_template = """You are a relevance router for a shopping assistant that answers questions about products in stock.

## Instructions

- Determine whether the question is about products, inventory, or purchasing.
- Questions about product features, availability, pricing, comparisons, and recommendations are relevant.
- Questions about store policies, personal advice, or unrelated topics are not relevant.

## Examples

Question: "Do you have running shoes under $100?"
Relevant: yes

Question: "What's the weather like today?"
Relevant: no - not related to products

Question: "Can you help me write an essay?"
Relevant: no - not related to products

Question: "Which laptop has the best battery life?"
Relevant: yes

Question: "What's your return policy?"
Relevant: no - about store policy, not product information
"""

    template = Template(prompt_template)

    prompt = template.render()

    messages = state.messages

    conversation = []

    for message in messages:
        conversation.append(convert_to_openai_messages(message))

    client = instructor.from_provider(
        "openai/gpt-5.4-mini",
        mode=instructor.Mode.RESPONSES_TOOLS
    )

    response, raw_response = client.create_with_completion(
        messages=[
            {"role": "system", "content": prompt},
            *conversation
        ],
        reasoning={"effort": "none"},
        response_model=IntentRouterResponse
    )

    return {
        "question_relevant": response.question_relevant,
        "answer": response.answer
    }

# %%
def intent_router_conditional_edges(state: State) -> str:
    if state.question_relevant:
        return "agent_node"
    else:
        return "end"

# %% [markdown]
# ### Graph Construction

# %%
workflow = StateGraph(State)

tools = [get_formatted_item_context]
tool_node = ToolNode(tools)

workflow.add_node("tool_node", tool_node)
workflow.add_node("agent_node", agent_node)
workflow.add_node("intent_router_node", intent_router_node)

workflow.add_edge(START, "intent_router_node")

workflow.add_conditional_edges(
    "intent_router_node",
    intent_router_conditional_edges,
    {
        "agent_node": "agent_node",
        "end": END
    }
)

workflow.add_conditional_edges(
    "agent_node",
    tool_router,
    {
        "tools": "tool_node",
        "end": END
    }
)

workflow.add_edge("tool_node", "agent_node")

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?")]
}

# %%
result = graph.invoke(initial_state)

# %%
result
# Out:
# {'messages': [HumanMessage(content='Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content=[{'arguments': '{"query":"tablet for a kid, child-friendly tablet, kids tablet in stock","top_k":5}', 'call_id': 'call_jFzyccaPlJDpCggqHgWRGQex', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0691fdb453d5f014006a59575469b48196b6acf4ea8d4c4e37', 'status': 'completed'}, {'arguments': '{"query":"watch for adult, smartwatch, watch in stock","top_k":5}', 'call_id': 'call_Ci3RbEBByt7grOIUQGsXV4nZ', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0691fdb453d5f014006a59575469c481969e15e19bf40abfd8', 'status': 'completed'}, {'arguments': '{"query":"laptop for wife, laptop, notebook computer in stock","top_k":5}', 'call_id': 'call_tbRPJEzBoGWF6pgP24NPYGE9', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0691fdb453d5f014006a59575469c8819697eebe248a36a74d', 'status': 'completed'}, {'arguments': '{"query":"waterproof speaker, waterproof bluetooth speaker, speaker in stock","top_k":5}', 'call_id': 'call_QE2O55N8wVj8y1TlcVnzoDHW', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0691fdb453d5f014006a59575469d0819698d60ba9f7d86304', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0691fdb453d5f014006a5957530e3c8196897b5f5a922cfc7b', 'created_at': 1784239955.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_0691fdb453d5f014006a5957530e3c8196897b5f5a922cfc7b', tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'tablet for a kid, child-friendly tablet, kids tablet in stock', 'top_k': 5}, 'id': 'call_jFzyccaPlJDpCggqHgWRGQex', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'watch for adult, smartwatch, watch in stock', 'top_k': 5}, 'id': 'call_Ci3RbEBByt7grOIUQGsXV4nZ', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'laptop for wife, laptop, notebook computer in stock', 'top_k': 5}, 'id': 'call_tbRPJEzBoGWF6pgP24NPYGE9', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'waterproof speaker, waterproof bluetooth speaker, speaker in stock', 'top_k': 5}, 'id': 'call_QE2O55N8wVj8y1TlcVnzoDHW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 398, 'output_tokens': 148, 'total_tokens': 546, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#   ToolMessage(content='- ID: B0B3R74TZC, rating: 3.7, description: Kids Tablet 7 inch WiFi Kids Tablets 32G Android 10 Tablet for Kids Dual Camera Educational Games Parental Control with Kids Software Pre-Installed Kid-Proof YouTube Netflix for Boys Girls(Blue) 【 NEW VERSION TABLET FOR KIDS THAT GLOWS WITH TODDLERS】Our Multi-Functional Kids Tablet comes with GMS Certified IWAWA Kids Apps Preloaded Equipped with an adjustable stand. This kids tablet is equipped with a quad-core CPU and Android operating system, running smoothly. 1GB RAM + 32GB ROM + expandable memory (Supports up to 32G SD Card, Card is not included). 1024×600 HD IPS display brings clear and vivid images, which can effectively protect children\'s eyesight Newest Android 10.0 OS , best kid-friendly companion, Inspire kids imagination and creativity 【Premium Parental Control】- The kids tablet has an advanced parental control mode, the screen
. Invest in your health today! ⌚【Unleash Your Athletic Potential】Smart watch for men android comes with 20 sport modes. Including walking, running, cycling and more. Enjoy your favorite tunes while exercising, and use the watch to track your progress and set new records. Make fitness fun and stay motivated with our smart watch. ⌚【Practical Features That Matter】Get more than just a watch with our multifunctional device. Set the time, receive notifications for calls and messages, control your music, check the weather, find your phone or watch, use the stopwatch, timer, alarm, game, receipt code, social code, calculator, NFC door card, and much more. Never miss a beat with our versatile and practical smart watch. ⌚【Larger Display, Better Experience】iOS Android smart watch Immerse yourself in the 1.8-inch super large color high-definition display, featuring amazing quality and expansive visuals. Choose from over 200 custom watch faces or upload your own photos to create a personalized look. Stand out from the crowd and enjoy a better interactive experience with our smart watch.\n- ID: B0BYRXT52V, rating: 4.3, description: 【2023 NEW】 Smart Watch for Men Women (Answer/Make Call), 1.8\'\' Waterproof Fitness Tracker Watch with Alexa, , Heart Rate SpO2 Monitor Sleep, 100+ Sports, Bluetooth Smartwatch for Android iPhone… 【1.8" Full Touch Color Screen & 120+ New Dials】1.8" HD brilliant big screen, strong and durable Panda Glass, bring you comfortable visual experience and smooth user experience. 5 levels of brightness are adjustable, 120+ new dial trend are optional. In addition, you can upload your favorite pictures or photos to make your own unique style. Stylish appearance, clear large screen, comfortable liquid silicone strap, it is the best fitness watch choice. 【ALEXA Built-in Makes Life Convenient】You can talk to Alexa on your smartwatch to control music playback, encyclopedia query, read news and get information, check the weather, set alarms, control access to third-party smarthard home devices on Amazon platform, and more. It makes things on your wrist simple and easy, and will always work as your convenient life assistant. 【 All-Day Activity Tracking & Health Tracking 】Built-in new upgraded chip, minimum size, lowest power consumption, highest integration. The full accuracy of the data and the battery life is longer! Record your daily walking steps, distance counter, calories burned, active minutes, and continuously monitor your heart rate, blood oxygen, stress, and sleep quality with detailed data, analyze and remind you of your physical status and trends from your wrist, help you adjust a healthier lifestyle. 【Answer/Make Call & Smart Notifications】Smartwatches built-in speaker, after connecting to your phone via Bluetooth, you can answer/make calls directly from your fitness tracker. Never miss an important call while running or driving. Also it supports multiple smart remind ...
#   ToolMessage(content='- ID: B0C9ZWCZ99, rating: 4.3, description: HP 15.6" HD Busienss Laptop Newest, 6-core AMD Ryzen 5 5500U(up to 4.0GHz), 8GB RAM, 256GB SSD, USB-A&C, WiFi, Fast Charge, Windows 11 + GM Accessory 【15.6" HD micro-edge Display】Revolutionize your display and see more of what you love with this slim bezel design that maximizes your viewing area foor an immersive multimedia experience. 【AMD Ryzen 5 5500U Mobile Processor】Create. Play. Work. Educate. Entertain. The possibilities are infinite. Be anywhere, go anywhere. Powers ultrathin notebooks that offer supreme performance, astonishing battery life, and modern features you need on-the-go. 【Upgraded to 8GB system memory for advanced multitasking】Substantial high-bandwidth RAM to smoothly run your games and photo and video-editing applications, as well as multiple programs and browser tabs all at once. 【Upgraded to 256GB SSD Storage】Boot up in seconds, get to files faster, and have room for loads of files with the lightning-quick solid state drive. 【Windows 11 Home】Windows 11 is the place to think, express, and create in a natural way. 2 x USB-A; 1 x USB-C; 1XHDMI.\n- ID: B09XJJNCXZ, rating: 4.5, description: HP Newest Notebook Laptop, 14" HD Touchscreen, Intel
clip on-Equipped with suction cups and removable metal hooks, it can be easily attached to shower walls, tiles and mirrors, and you can also use the hooks to hang the portable speaker on your backpack while hiking. Easy to Pair- The waterproof shower speaker is compatible with all bluetooth devices, phones, computers and even the Echo range. Bluetooth ensures instant pairing of waterproof speakers and maintains a strong connection up to 33 feet. Built in Microphones- The built-in microphone provides clear hands-free calls in the shower, cooking, hiking, kayaking and more.\n- ID: B0CB3CLQYS, rating: 4.9, description: neza Portable Bluetooth Speaker, 20W HD Loud Stereo Sound Wireless Speaker, 18H Playtime Bluetooth Speakers with RGB Flashing Lights, Bluetooth 5.1, IPX7 Waterproof Speakers for Travel/Home/Purple Vibrant Light and Effects 360° Stereo: The portable bluetooth speaker is equipped with color RGB light effects, the gradient lights flash, phase and shine to the beat of the music, creating a vibrant ambiance. The wireless speaker features two built-in 10W speakers, is the best choice for those who need high-quality sound for large areas, such as tailgate parties and neighborhood barbecues. Portable speaker sounds beautiful, with smooth vocals, ample bass, and surprising ambience. IPX7 Waterproof and Portable Design: This waterproof bluetooth speaker is IPX7 waterproof, and rugged speakers suitable for outdoor adventures. These makes waterproof speaker safe in the rain or in the shower. It about 6.69 inches high and 1.01 pounds, it‘s the type of water proof speaker you can just toss in a backpack or suitcase, and comes with a rope that can be used for hanging, it is light enough that most people can carry it easily. Long Battery Life and Fast Charging: The outdoor speaker is equipped with a 4400mAh large-capacity battery, which does not require frequent charging, and can play continuously for more than 18 hours on a single charge. Enjoy music day to night never stop, happiness never ends. Thanks to the USB-C charging, anyone who has USB-C–equipped mobile devices won’t have to carry an extra charging cable for the bluetooth speakers when they travel, charging is more convenient and efficient. Multiple Play Modes: Anyone who owns a smartphone or tablet is likely to enjoy owning a portable Bluetooth speaker. This wireless portable bluetooth speaker provides multiple play modes, including FM radio, USB mode and Bluetooth music, etc. You can listen to your favorite radio shows anytime, anywhere, or play audio directly by plugging in a USB stick or connecting via Bluetooth. Whatever your preferred music source, this portable bluetooth wireless speakers has you covered. Bluetooth 5.1 and Built-in Microphone: This outdoor portable speaker uses Bluetooth 5.1 technology for faster and stable connections. It\'s maintains a connection up to 100 feet away, allowing you to move freely without interruption. Bluetooth speakers don’t require the use of special apps—whatever you play on your phone will play through the speaker. The portable bluetooth soundbox with Mic can clearly capture the sound, You can easily use the Bluetooth speaker to answer the call.\n- ID: B0C996WY16, rating: 4.7, description: Raymate Bluetooth Speakers, HiFi Stereo Sound with DSP, 30W IPX7 Wat ...
#   AIMessage(content=[{'arguments': '{"answer":"Yes — I found available products for each item on your list:\\n\\n**Tablet for your kid**\\n- **B0C7DCS2KW** — KYASTER Kids Tablet, 7 inch, Android 12\\n  - 7\\" Full HD 1920×1200 IPS screen\\n  - 2GB RAM, 32GB ROM\\n  - EVA kids-proof case with stylus\\n  - Parental controls and kids education apps\\n  - Suitable for younger children\\n- **B0B159KDFP** — G-TiDE Kids Tablet, 7 inch\\n  - 7\\" tablet with 32GB storage and 2GB RAM\\n  - 5MP dual camera\\n  - Parental control app included\\n  - Shoulder strap and protective case\\n  - Aged for kids, especially around 3–7 years old\\n\\n**Watch for you**\\n- **B0BYRXT52V** — Smart Watch for Men Women\\n  - 1.8\\" full-touch color screen\\n  - Answer/make calls\\n  - Alexa built in\\n  - Heart rate, SpO2, sleep tracking\\n  - IP68 waterproof\\n- **B0CFLR6R3X** — SOUYIE Smart Watch for Men Women\\n  - 1.8\\" HD display\\n  - Bluetooth calling\\n  - Blood pressure, heart rate, temperature, sleep monitoring\\n  - IP67 waterproof\\n\\n**Laptop for your wife**\\n- **B09XJJNCXZ** — HP Newest Notebook Laptop, 14\\" HD Touchscreen\\n  - Intel Core i3-1115G4 processor\\n  - 8GB RAM, 128GB SSD\\n  - 14\\" HD touchscreen\\n  - Wi‑Fi and Bluetooth\\n- **B0C9ZWCZ99** — HP 15.6\\" HD Business Laptop\\n  - AMD Ryzen 5 5500U\\n  - 8GB RAM, 256GB SSD\\n  - 15.6\\" HD display\\n  - Windows 11\\n- **B0B9XSS7DC** — jumper 2 in 1 Laptop, 11.6\\" touch screen\\n  - Intel Celeron N4000\\n  - 4GB RAM, 128GB eMMC\\n  - 2-in-1 flip design\\n  - Windows 11\\n\\n**Waterproof speaker**\\n- **B0CB3CLQYS** — neza Portable Bluetooth Speaker\\n  - IPX7 waterproof\\n  - 20W HD loud stereo sound\\n  - 18 hours playtime\\n  - Bluetooth 5.1\\n  - RGB flashing lights\\n- **B0C996WY16** — Raymate Bluetooth Speakers\\n  - IPX7 waterproof\\n  - 30W stereo sound with DSP\\n  - Portable design\\n  - 1000 minutes playtime\\n- **B0BRB22GL4** — MIFA Portable Waterproof Bluetooth Speaker\\n  - IP67 waterproof and dustproof\\n  - 20W output\\n  - 38 hours playtime\\n  - Power bank function\\n\\nIf you want, I can help narrow these down by budget, screen size, battery life, or age range for the kid\'s tablet.","references":[{"id":"B0C7DCS2KW","description":"KYASTER Kids Tablet, 7 inch Tablet for Kids, Android 12, 2GB RAM 32GB ROM, EVA kids-proof case with stylus, parental controls"},{"id":"B0B159KDFP","description":"G-TiDE Kids Tablet, 7 inch Tablet for Kids, 32GB+2GB, 5MP dual camera, parental control app, case and shoulder strap"},{"id":"B0BYRXT52V","description":"Smart Watch for Men Women, 1.8\'\' Waterproof Fitness Tracker Watch with Alexa, heart rate/SpO2 monitoring, IP68 waterproof"},{"id":"B0CFLR6R3X","description":"SOUYIE Smart Watch for Men Women, Bluetooth calling, 1.8 Inch HD display, blood pressure/heart rate/temperature monitoring, IP67 waterproof"},{"id":"B09XJJNCXZ","description":"HP Newest Notebook Laptop, 14\\" HD Touchscreen, Intel Core i3-1115G4, 8GB RAM, 128GB SSD"},{"id":"B0C9ZWCZ99","description":"HP 15.6\\" HD Business Laptop, AMD Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11"},{"id":"B0B9XSS7DC","description":"jumper 2 in 1 Laptop, 11.6 Inch Flip Touch Screen, Intel Celeron N4000, 4GB RAM, 128GB eMMC, Windows 11"},{"id":"B0CB3CLQYS","description":"neza Portable Bluetooth Speaker, 20W HD Loud Stereo Sound, IPX7 Waterproof, 18H playtime"},{"id":"B0C996WY16","description":"Raymate Bluetooth Speakers, 30W HiFi Stereo Sound, IPX7 Waterproof, Portable Speaker"},{"id":"B0BRB22GL4","description":"MIFA Portable Waterproof Bluetooth Speaker, IP67 Waterproof and Dustproof, 20W, 38hrs playtime"}]}', 'call_id': 'call_hfLIG0AZ01n47pwVfFAXzszZ', 'name': 'FinalResponse', 'type': 'function_call', 'id': 'fc_0691fdb453d5f014006a59575ac348819684f2d4fb3bf4fa8b', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0691fdb453d5f014006a595759f2cc8196be06b2219634aa2e', 'created_at': 1784239962.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': ' ...
#  'question_relevant': True,
#  'iteration': 2,
#  'answer': 'Yes — I found available products for each item on your list:\n\n**Tablet for your kid**\n- **B0C7DCS2KW** — KYASTER Kids Tablet, 7 inch, Android 12\n  - 7" Full HD 1920×1200 IPS screen\n  - 2GB RAM, 32GB ROM\n  - EVA kids-proof case with stylus\n  - Parental controls and kids education apps\n  - Suitable for younger children\n- **B0B159KDFP** — G-TiDE Kids Tablet, 7 inch\n  - 7" tablet with 32GB storage and 2GB RAM\n  - 5MP dual camera\n  - Parental control app included\n  - Shoulder strap and protective case\n  - Aged for kids, especially around 3–7 years old\n\n**Watch for you**\n- **B0BYRXT52V** — Smart Watch for Men Women\n  - 1.8" full-touch color screen\n  - Answer/make calls\n  - Alexa built in\n  - Heart rate, SpO2, sleep tracking\n  - IP68 waterproof\n- **B0CFLR6R3X** — SOUYIE Smart Watch for Men Women\n  - 1.8" HD display\n  - Bluetooth calling\n  - Blood pressure, heart rate, temperature, sleep monitoring\n  - IP67 waterproof\n\n**Laptop for your wife**\n- **B09XJJNCXZ** — HP Newest Notebook Laptop, 14" HD Touchscreen\n  - Intel Core i3-1115G4 processor\n  - 8GB RAM, 128GB SSD\n  - 14" HD touchscreen\n  - Wi‑Fi and Bluetooth\n- **B0C9ZWCZ99** — HP 15.6" HD Business Laptop\n  - AMD Ryzen 5 5500U\n  - 8GB RAM, 256GB SSD\n  - 15.6" HD display\n  - Windows 11\n- **B0B9XSS7DC** — jumper 2 in 1 Laptop, 11.6" touch screen\n  - Intel Celeron N4000\n  - 4GB RAM, 128GB eMMC\n  - 2-in-1 flip design\n  - Windows 11\n\n**Waterproof speaker**\n- **B0CB3CLQYS** — neza Portable Bluetooth Speaker\n  - IPX7 waterproof\n  - 20W HD loud stereo sound\n  - 18 hours playtime\n  - Bluetooth 5.1\n  - RGB flashing lights\n- **B0C996WY16** — Raymate Bluetooth Speakers\n  - IPX7 waterproof\n  - 30W stereo sound with DSP\n  - Portable design\n  - 1000 minutes playtime\n- **B0BRB22GL4** — MIFA Portable Waterproof Bluetooth Speaker\n  - IP67 waterproof and dustproof\n  - 20W output\n  - 38 hours playtime\n  - Power bank function\n\nIf you want, I can help narrow these down by budget, screen size, battery life, or age range for the kid\'s tablet.',
#  'final_answer': True,
#  'references': [{'id': 'B0C7DCS2KW',
#    'description': 'KYASTER Kids Tablet, 7 inch Tablet for Kids, Android 12, 2GB RAM 32GB ROM, EVA kids-proof case with stylus, parental controls'},
#   {'id': 'B0B159KDFP',
#    'description': 'G-TiDE Kids Tablet, 7 inch Tablet for Kids, 32GB+2GB, 5MP dual camera, parental control app, case and shoulder strap'},
#   {'id': 'B0BYRXT52V',
#    'description': "Smart Watch for Men Women, 1.8'' Waterproof Fitness Tracker Watch with Alexa, heart rate/SpO2 monitoring, IP68 waterproof"},
#   {'id': 'B0CFLR6R3X',
#    'description': 'SOUYIE Smart Watch for Men Women, Bluetooth calling, 1.8 Inch HD display, blood pressure/heart rate/temperature monitoring, IP67 waterproof'},
#   {'id': 'B09XJJNCXZ',
#    'description': 'HP Newest Notebook Laptop, 14" HD Touchscreen, Intel Core i3-1115G4, 8GB RAM, 128GB SSD'},
#   {'id': 'B0C9ZWCZ99',
#    'description': 'HP 15.6" HD Business Laptop, AMD Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11'},
#   {'id': 'B0B9XSS7DC',
#    'description': 'jumper 2 in 1 Laptop, 11.6 Inch Flip Touch Screen, Intel Celeron N4000, 4GB RAM, 128GB eMMC, Windows 11'},
#   {'id': 'B0CB3CLQYS',
#    'description': 'neza Portable Bluetooth Speaker, 20W HD Loud Stereo Sound, IPX7 Waterproof, 18H playtime'},
#   {'id': 'B0C996WY16',
#    'description': 'Raymate Bluetooth Speakers, 30W HiFi Stereo Sound, IPX7 Waterproof, Portable Speaker'},
#   {'id': 'B0BRB22GL4',
#    'description': 'MIFA Portable Waterproof Bluetooth Speaker, IP67 Waterproof and Dustproof, 20W, 38hrs playtime'}]}

# %%
print(result["answer"])
# Out:
# Yes — I found available products for each item on your list:
#
# **Tablet for your kid**
# - **B0C7DCS2KW** — KYASTER Kids Tablet, 7 inch, Android 12
#   - 7" Full HD 1920×1200 IPS screen
#   - 2GB RAM, 32GB ROM
#   - EVA kids-proof case with stylus
#   - Parental controls and kids education apps
#   - Suitable for younger children
# - **B0B159KDFP** — G-TiDE Kids Tablet, 7 inch
#   - 7" tablet with 32GB storage and 2GB RAM
#   - 5MP dual camera
#   - Parental control app included
#   - Shoulder strap and protective case
#   - Aged for kids, especially around 3–7 years old
#
# **Watch for you**
# - **B0BYRXT52V** — Smart Watch for Men Women
#   - 1.8" full-touch color screen
#   - Answer/make calls
#   - Alexa built in
#   - Heart rate, SpO2, sleep tracking
#   - IP68 waterproof
# - **B0CFLR6R3X** — SOUYIE Smart Watch for Men Women
#   - 1.8" HD display
#   - Bluetooth calling
#   - Blood pressure, heart rate, temperature, sleep monitoring
#   - IP67 waterproof
#
# **Laptop for your wife**
# - **B09XJJNCXZ** — HP Newest Notebook Laptop, 14" HD Touchscreen
#   - Intel Core i3-1115G4 processor
#   - 8GB RAM, 128GB SSD
#   - 14" HD touchscreen
#   - Wi‑Fi and Bluetooth
# - **B0C9ZWCZ99** — HP 15.6" HD Business Laptop
#   - AMD Ryzen 5 5500U
#   - 8GB RAM, 256GB SSD
#   - 15.6" HD display
#   - Windows 11
# - **B0B9XSS7DC** — jumper 2 in 1 Laptop, 11.6" touch screen
#   - Intel Celeron N4000
#   - 4GB RAM, 128GB eMMC
#   - 2-in-1 flip design
#   - Windows 11
#
# **Waterproof speaker**
# - **B0CB3CLQYS** — neza Portable Bluetooth Speaker
#   - IPX7 waterproof
#   - 20W HD loud stereo sound
#   - 18 hours playtime
#   - Bluetooth 5.1
#   - RGB flashing lights
# - **B0C996WY16** — Raymate Bluetooth Speakers
#   - IPX7 waterproof
#   - 30W stereo sound with DSP
#   - Portable design
#   - 1000 minutes playtime
# - **B0BRB22GL4** — MIFA Portable Waterproof Bluetooth Speaker
#   - IP67 waterproof and dustproof
#   - 20W output
#   - 38 hours playtime
#   - Power bank function
#
# If you want, I can help narrow these down by budget, screen size, battery life, or age range for the kid's tablet.
